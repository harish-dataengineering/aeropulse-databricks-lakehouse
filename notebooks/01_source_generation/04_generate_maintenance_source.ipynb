# %% [markdown]
# # AeroPulse — Maintenance Event Source Generation
#
# ## Purpose
#
# Generate synthetic maintenance events representing
# records produced by the operational maintenance application.
#
# ## Source System
#
# Maintenance Application
#
# ## Entity
#
# Maintenance Events
#
# ## Source Format
#
# JSON
#
# ## Target
#
# Development Raw Landing Volume
#
# ## Future Ingestion Pattern
#
# Auto Loader

# %%
# %run /Users/hclearningtools08@gmail.com/aeropulse-databricks-lakehouse/src/source_generators/maintenance_generator.py

# %%
maintenance_df = generate_maintenance_events(
    spark=spark,
    record_count=5000,
)

print(
    f"Generated maintenance events: "
    f"{maintenance_df.count()}"
)

# %%
maintenance_df.printSchema()

# %%
display(
    maintenance_df.limit(20)
)

# %%
display(
    maintenance_df
    .groupBy("aircraft_id")
    .count()
    .orderBy("aircraft_id")
)

# %%
display(
    maintenance_df
    .groupBy("engine_id")
    .count()
    .orderBy("engine_id")
)

# %%
display(
    maintenance_df
    .groupBy("maintenance_type")
    .count()
    .orderBy("maintenance_type")
)

# %%
display(
    maintenance_df
    .groupBy("severity")
    .count()
    .orderBy("severity")
)

# %%
display(
    maintenance_df
    .groupBy("maintenance_status")
    .count()
    .orderBy("maintenance_status")
)

# %%
MAINTENANCE_SOURCE_PATH = (
    "/Volumes/workspace/aeropulse_dev/"
    "raw_landing/maintenance_app/maintenance"
)

print(MAINTENANCE_SOURCE_PATH)

# %%
from datetime import datetime, timezone

delivery_timestamp = datetime.now(
    timezone.utc
).strftime("%Y%m%d_%H%M%S")

# %%
delivery_path = (
    f"{MAINTENANCE_SOURCE_PATH}/"
    f"maintenance_{delivery_timestamp}"
)

print(delivery_path)

# %%
(
    maintenance_df.write
    .mode("error")
    .json(delivery_path)
)

# %%
display(
    dbutils.fs.ls(
        MAINTENANCE_SOURCE_PATH
    )
)

# %%
maintenance_check_df = (
    spark.read
    .json(delivery_path)
)

# %%
print(
    f"Records in delivered file: "
    f"{maintenance_check_df.count()}"
)

# %%
maintenance_df_2 = generate_maintenance_events(
    spark=spark,
    record_count=3000,
)

# %%
print(
    f"Second delivery records: "
    f"{maintenance_df_2.count()}"
)

# %%
delivery_timestamp_2 = datetime.now(
    timezone.utc
).strftime("%Y%m%d_%H%M%S_%f")

# %%
delivery_path_2 = (
    f"{MAINTENANCE_SOURCE_PATH}/"
    f"maintenance_{delivery_timestamp_2}"
)

# %%
(
    maintenance_df_2.write
    .mode("error")
    .json(delivery_path_2)
)

# %%
display(
    dbutils.fs.ls(
        MAINTENANCE_SOURCE_PATH
    )
)
