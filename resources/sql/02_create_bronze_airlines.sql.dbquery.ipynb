-- %%
-- AeroPulse Enterprise Lakehouse Platform
-- Bronze airlines table
-- Environment: Development

CREATE TABLE IF NOT EXISTS workspace.aeropulse_dev.bronze_airlines
(
    airline_id STRING,
    airline_code STRING,
    airline_name STRING,
    country STRING,
    region STRING,
    founded_year STRING,
    fleet_size STRING,
    status STRING,
    source_updated_timestamp STRING,

    _ingestion_timestamp TIMESTAMP NOT NULL,
    _source_file_path STRING NOT NULL,
    _source_system STRING NOT NULL,
    _pipeline_run_id STRING NOT NULL
)
USING DELTA ;
