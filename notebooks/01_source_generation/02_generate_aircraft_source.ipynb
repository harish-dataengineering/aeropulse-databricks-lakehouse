# %% [markdown]
# # AeroPulse — Aircraft Source Generation
#
# Generates synthetic aircraft master data representing
# data received from the ERP source system.
#
# Source format:
# JSON
#
# Target landing layer:
# Development Raw Landing Volume

# %%
# %run /Users/hclearningtools08@gmail.com/aeropulse-databricks-lakehouse/src/source_generators/aircraft_generator.py

# %%
aircraft_df = generate_aircraft(
    spark=spark,
    record_count=1000,
)

print(
    f"Generated aircraft records: "
    f"{aircraft_df.count()}"
)

# %%
display(
    aircraft_df
)

# %%
aircraft_df.printSchema()

# %%
display(
    aircraft_df.groupBy(
        "airline_id"
    )
    .count()
    .orderBy("airline_id")
)

# %%
from datetime import datetime, timezone

batch_timestamp = datetime.now(
    timezone.utc
).strftime("%Y%m%d_%H%M%S")

AIRCRAFT_SOURCE_PATH = (
    f"/Volumes/workspace/aeropulse_dev/"
    f"raw_landing/erp/aircraft/"
    f"aircraft_{batch_timestamp}.json"
)

print(AIRCRAFT_SOURCE_PATH)

# %%
(
    aircraft_df.write
    .mode("error")
    .json(AIRCRAFT_SOURCE_PATH)
)

print(
    f"Aircraft JSON delivery created:\n"
    f"{AIRCRAFT_SOURCE_PATH}"
)

# %%
display(
    dbutils.fs.ls(
        "/Volumes/workspace/aeropulse_dev/"
        "raw_landing/erp/aircraft"
    )
)

# %%
display(
    dbutils.fs.ls(
        AIRCRAFT_SOURCE_PATH
    )
)

# %%
aircraft_json_df = (
    spark.read
    .json(AIRCRAFT_SOURCE_PATH)
)

# %%
print(
    f"JSON records read: "
    f"{aircraft_json_df.count()}"
)

# %%
aircraft_json_df.printSchema()

# %%
display(
    aircraft_json_df.limit(10)
)
